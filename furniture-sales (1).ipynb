# %%
# This Python 3 environment comes with many helpful analytics libraries installed
# It is defined by the kaggle/python Docker image: https://github.com/kaggle/docker-python
# For example, here's several helpful packages to load

import numpy as np # linear algebra
import pandas as pd # data processing, CSV file I/O (e.g. pd.read_csv)

# Input data files are available in the read-only "../input/" directory
# For example, running this (by clicking run or pressing Shift+Enter) will list all files under the input directory

import os
for dirname, _, filenames in os.walk('/kaggle/input'):
    for filename in filenames:
        print(os.path.join(dirname, filename))

# You can write up to 20GB to the current directory (/kaggle/working/) that gets preserved as output when you create a version using "Save & Run All" 
# You can also write temporary files to /kaggle/temp/, but they won't be saved outside of the current session
# Out:
# /kaggle/input/sample-super-store/Super_Store_data (1).csv

# %% [markdown]
# # Installing the required packages

# %%
import pandas as pd
import numpy as np
import matplotlib.pyplot as plt
import itertools
import warnings
import matplotlib
import statsmodels.api as sm
plt.style.use('fivethirtyeight')
matplotlib.rcParams['axes.labelsize']=14
matplotlib.rcParams['xtick.labelsize']=12
matplotlib.rcParams['ytick.labelsize']=12
matplotlib.rcParams['text.color']='k'

# %%
warnings.filterwarnings("ignore")
plt.style.use('fivethirtyeight')
plt.rcParams['axes.labelsize']=14
plt.rcParams['xtick.labelsize']=12
plt.rcParams['ytick.labelsize']=12
plt.rcParams['text.color']='k'

# %% [markdown]
# # Reading the Time Series Data

# %%
df=pd.read_csv('/kaggle/input/sample-super-store/Super_Store_data (1).csv',encoding = 'cp1252')
df.head()
# Out:
#    Row ID        Order ID  Order Date   Ship Date       Ship Mode Customer ID  \
# 0       1  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 1       2  CA-2016-152156   11/8/2016  11/11/2016    Second Class    CG-12520
# 2       4  US-2015-108966  10/11/2015  10/18/2015  Standard Class    SO-20335
# 3       6  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
# 4      11  CA-2014-115812    6/9/2014   6/14/2014  Standard Class    BH-11710
#
#      Customer Name   Segment        Country             City  ... Postal Code  \
# 0      Claire Gute  Consumer  United States        Henderson  ...       42420
# 1      Claire Gute  Consumer  United States        Henderson  ...       42420
# 2   Sean O'Donnell  Consumer  United States  Fort Lauderdale  ...       33311
# 3  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
# 4  Brosina Hoffman  Consumer  United States      Los Angeles  ...       90032
#
#    Region       Product ID   Category Sub-Category  \
# 0   South  FUR-BO-10001798  Furniture    Bookcases
# 1   South  FUR-CH-10000454  Furniture       Chairs
# 2   South  FUR-TA-10000577  Furniture       Tables
# 3    West  FUR-FU-10001487  Furniture  Furnishings
# 4    West  FUR-TA-10001539  Furniture       Tables
#
#                                         Product Name      Sales  Quantity  \
# 0                  Bush Somerset Collection Bookcase   261.9600         2
# 1  Hon Deluxe Fabric Upholstered Stacking Chairs,...   731.9400         3
# 2      Bretford CR4500 Series Slim Rectangular Table   957.5775         5
# 3  Eldon Expressions Wood and Plastic Desk Access...    48.8600         7
# 4           Chromcraft Rectangular Conference Tables  1706.1840         9
#
#    Discount    Profit
# 0      0.00   41.9136
# 1      0.00  219.5820
# 2      0.45 -383.0310
# 3      0.00   14.1694
# 4      0.20   85.3092
#
# [5 rows x 21 columns]

# %%
df['Category'].unique()
# Out:
# array(['Furniture'], dtype=object)

# %%
df.shape
# Out:
# (2121, 21)

# %%
df.describe(include='O')
# Out:
#               Order ID Order Date  Ship Date       Ship Mode Customer ID  \
# count             2121       2121       2121            2121        2121
# unique            1764        889        960               4         707
# top     US-2015-129007   9/5/2016  12/6/2017  Standard Class    SV-20365
# freq                 4         10         10            1248          15
#
#        Customer Name   Segment        Country           City       State  \
# count           2121      2121           2121           2121        2121
# unique           707         3              1            371          48
# top      Seth Vernon  Consumer  United States  New York City  California
# freq              15      1113           2121            192         444
#
#        Region       Product ID   Category Sub-Category  \
# count    2121             2121       2121         2121
# unique      4              375          1            4
# top      West  FUR-FU-10004270  Furniture  Furnishings
# freq      707               16       2121          957
#
#                       Product Name
# count                         2121
# unique                         380
# top     KI Adjustable-Height Table
# freq                            18

# %%
df.describe(include='float64')
# Out:
#              Sales     Discount       Profit
# count  2121.000000  2121.000000  2121.000000
# mean    349.834887     0.173923     8.699327
# std     503.179145     0.181547   136.049246
# min       1.892000     0.000000 -1862.312400
# 25%      47.040000     0.000000   -12.849000
# 50%     182.220000     0.200000     7.774800
# 75%     435.168000     0.300000    33.726600
# max    4416.174000     0.700000  1013.127000

# %%
df.describe(include='int64')
# Out:
#             Row ID   Postal Code     Quantity
# count  2121.000000   2121.000000  2121.000000
# mean   5041.643564  55726.556341     3.785007
# std    2885.740258  32261.888225     2.251620
# min       1.000000   1040.000000     1.000000
# 25%    2568.000000  22801.000000     2.000000
# 50%    5145.000000  60505.000000     3.000000
# 75%    7534.000000  90032.000000     5.000000
# max    9991.000000  99301.000000    14.000000

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# RangeIndex: 2121 entries, 0 to 2120
# Data columns (total 21 columns):
#  #   Column         Non-Null Count  Dtype
# ---  ------         --------------  -----
#  0   Row ID         2121 non-null   int64
#  1   Order ID       2121 non-null   object
#  2   Order Date     2121 non-null   object
#  3   Ship Date      2121 non-null   object
#  4   Ship Mode      2121 non-null   object
#  5   Customer ID    2121 non-null   object
#  6   Customer Name  2121 non-null   object
#  7   Segment        2121 non-null   object
#  8   Country        2121 non-null   object
#  9   City           2121 non-null   object
#  10  State          2121 non-null   object
#  11  Postal Code    2121 non-null   int64
#  12  Region         2121 non-null   object
#  13  Product ID     2121 non-null   object
#  14  Category       2121 non-null   object
#  15  Sub-Category   2121 non-null   object
#  16  Product Name   2121 non-null   object
#  17  Sales          2121 non-null   float64
#  18  Quantity       2121 non-null   int64
#  19  Discount       2121 non-null   float64
#  20  Profit         2121 non-null   float64
# dtypes: float64(3), int64(3), object(15)
# memory usage: 348.1+ KB

# %%
cols = ['Row ID', 'Order ID', 'Ship Date', 'Ship Mode', 'Customer ID', 'Customer Name', 'Segment', 'Country', 'City', 'State', 'Postal Code', 'Region', 'Product ID', 'Category', 'Sub-Category', 'Product Name', 'Quantity', 'Discount', 'Profit']
df.drop(cols,axis=1,inplace=True)

# %%
df=df.sort_values('Order Date')

# %%
df.isnull().sum()
# Out:
# Order Date    0
# Sales         0
# dtype: int64

# %%
df = df.groupby("Order Date")['Sales'].sum().reset_index()

# %%
df.head()
# Out:
#   Order Date     Sales
# 0   1/1/2017   975.490
# 1  1/10/2014    51.940
# 2  1/10/2015  1018.104
# 3  1/10/2016   104.770
# 4  1/11/2014     9.940

# %%
df['Order Date']=pd.to_datetime(df['Order Date'])
df.set_index('Order Date',inplace=True)

# %%
df.head()
# Out:
#                Sales
# Order Date
# 2017-01-01   975.490
# 2014-01-10    51.940
# 2015-01-10  1018.104
# 2016-01-10   104.770
# 2014-01-11     9.940

# %%
df.info()
# Out:
# <class 'pandas.core.frame.DataFrame'>
# DatetimeIndex: 889 entries, 2017-01-01 to 2017-09-09
# Data columns (total 1 columns):
#  #   Column  Non-Null Count  Dtype
# ---  ------  --------------  -----
#  0   Sales   889 non-null    float64
# dtypes: float64(1)
# memory usage: 13.9 KB

# %%
y=df['Sales'].resample('MS').mean()

# %%
y['2017']
# Out:
# Order Date
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %%
y
# Out:
# Order Date
# 2014-01-01     480.194231
# 2014-02-01     367.931600
# 2014-03-01     857.291529
# 2014-04-01     567.488357
# 2014-05-01     432.049188
# 2014-06-01     695.059242
# 2014-07-01     601.169500
# 2014-08-01     457.521656
# 2014-09-01     992.353367
# 2014-10-01     769.015437
# 2014-11-01     980.221486
# 2014-12-01    1532.298325
# 2015-01-01     978.328467
# 2015-02-01     522.395667
# 2015-03-01     781.236437
# 2015-04-01     805.822962
# 2015-05-01     624.996700
# 2015-06-01     428.565500
# 2015-07-01     719.706316
# 2015-08-01     602.412012
# 2015-09-01    1382.790684
# 2015-10-01     632.980184
# 2015-11-01    1286.701354
# 2015-12-01    1049.355418
# 2016-01-01     508.182867
# 2016-02-01     356.868273
# 2016-03-01     609.575810
# 2016-04-01     695.373158
# 2016-05-01     687.265227
# 2016-06-01     816.910750
# 2016-07-01     768.736412
# 2016-08-01     734.307782
# 2016-09-01    1135.953371
# 2016-10-01     624.872474
# 2016-11-01    1271.345152
# 2016-12-01    1410.719808
# 2017-01-01     397.602133
# 2017-02-01     528.179800
# 2017-03-01     544.672240
# 2017-04-01     453.297905
# 2017-05-01     678.302328
# 2017-06-01     826.460291
# 2017-07-01     562.524857
# 2017-08-01     857.881889
# 2017-09-01    1209.508583
# 2017-10-01     875.362728
# 2017-11-01    1277.817759
# 2017-12-01    1256.298672
# Freq: MS, Name: Sales, dtype: float64

# %% [markdown]
# # Visually checking the time series for trend and other components

# %%
plt.figure(figsize=(15,6))
y.plot()
# Out:
# <Axes: xlabel='Order Date'>

# %% [markdown]
# # Performing the Dicky Fuller Test

# %%
from statsmodels.tsa.stattools import adfuller
res=adfuller(y)
print("ADF Statistic: %f" % res[0]) 
      
print('P-value: %f' % res[1])  
      
print('Critical Values:')

for key, value in res[4].items():
    print('\t%s: %.3f' % (key, value))
# Out:
# ADF Statistic: -5.191070
# P-value: 0.000009
# Critical Values:
# 	1%: -3.621
# 	5%: -2.944
# 	10%: -2.610

# %% [markdown]
# # Decomposing

# %%
from statsmodels.tsa.seasonal import seasonal_decompose
decomposition = seasonal_decompose(y)
plt.figure(figsize=(15,6))
plt.plot(y, label = 'Original')
plt.legend(loc = 'best')


trend  = decomposition.trend
plt.show()
plt.figure(figsize=(15,6))
plt.plot(trend, label = "Trend")
plt.legend(loc  = "best")

seasonal = decomposition.seasonal
plt.show()
plt.figure(figsize=(15,6))
plt.plot(seasonal, label = 'Seasonal')
plt.legend(loc = 'best')

residual = decomposition.resid
plt.show()
plt.figure(figsize=(15,6))
plt.plot(residual, label = 'Residual')
plt.legend(loc = 'best')

# %%
p=d=q=range(0,2)
pdq = list(itertools.product(p,d,q))
seasonal_pdq = [(X[0], X[1], X[2], 12) for X in list(itertools.product(p, d, q))]
print('Examples of paramter combination for Seasonal ARIMA....')
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[1]))
print('SARIMAX: {} x {}'.format(pdq[1], seasonal_pdq[2]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[3]))
print('SARIMAX: {} x {}'.format(pdq[2], seasonal_pdq[4]))
# Out:
# Examples of paramter combination for Seasonal ARIMA....
# SARIMAX: (0, 0, 1) x (0, 0, 1, 12)
# SARIMAX: (0, 0, 1) x (0, 1, 0, 12)
# SARIMAX: (0, 1, 0) x (0, 1, 1, 12)
# SARIMAX: (0, 1, 0) x (1, 0, 0, 12)

# %% [markdown]
# # Forecasting using the best ARIMA(p,d,q) and Seasonality's(P,D,Q)

# %%
from pylab import rcParams  # Param means Parameter
import statsmodels.api as sm

for param in pdq:
    for param_seasonal in seasonal_pdq:
        try:
            mod = sm.tsa.statespace.SARIMAX(
                y, 
                order=param,
                seasonal_order=param_seasonal,
                enforce_stationarity=False,
                enforce_invertibility=False
            )
            results = mod.fit()
            print('ARIMA{}x{}12 - AIC:{}'.format(param, param_seasonal, results.aic))
        except Exception as e:
            print(f"An error occurred for ARIMA{param}x{param_seasonal}12: {e}")
            continue
# Out:
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.99048D+00    |proj g|=  1.66962D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      3      1     0     0   2.398D-07   7.990D+00
#   F =   7.9904349200061615
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 0, 0, 12)12 - AIC:769.0817523205915
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.89080D+01    |proj g|=  2.36417D-03
#   ys=-1.175E+02  -gs= 7.169E-01 BFGS update SKIPPED
#   ys=-1.145E+02  -gs= 7.246E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.40401D+01    |proj g|=  2.27397D+05
#   ys=-1.035E-01  -gs= 2.638E-01 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      6     86      4     3     0   2.274D+05   1.404D+01
#   F =   14.040081483616062
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 0)x(0, 0, 1, 12)12 - AIC:1351.8478224271419
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.96130D+00    |proj g|=  7.02705D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      6      1     0     0   3.189D-07   4.955D+00
#   F =   4.9553855530417819
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(0, 1, 0, 12)12 - AIC:477.7170130920111
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17740D+00    |proj g|=  1.58606D-01
#
# At iterate    5    f=  3.15483D+00    |proj g|=  4.29179D-03
#
# At iterate   10    f=  3.14156D+00    |proj g|=  1.12506D-01
#
# At iterate   15    f=  3.10698D+00    |proj g|=  6.55625D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     16     19      1     0     0   1.383D-05   3.107D+00
#   F =   3.1069821872850003
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(0, 1, 1, 12)12 - AIC:302.27028997936003
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.13783D+00    |proj g|=  5.06000D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     12      1     0     0   5.058D-05   5.138D+00
#   F =   5.1378275348107669
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 0)x(1, 0, 0, 12)12 - AIC:497.23144334183365
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70878D+01    |proj g|=  5.99853D-03
#   ys=-7.972E+01  -gs= 7.214E-01 BFGS update SKIPPED
#   ys=-8.199E+01  -gs= 7.228E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.46893D+01    |proj g|=  1.47616D+01
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      7     50      2     2     0   1.629D-14   1.469D+01
#   F =   14.689241352752505
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 0, 1, 12)12 - AIC:1416.1671698642406
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.27088D+00    |proj g|=  6.03846D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.038D-06   3.271D+00
#   F =   3.2708824990795216
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 0, 12)12 - AIC:318.0047199116341
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.17740D+00    |proj g|=  1.58606D-01
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  3.15658D+00    |proj g|=  3.15535D-02
#
# At iterate   10    f=  3.15479D+00    |proj g|=  1.07910D-03
#
# At iterate   15    f=  3.12010D+00    |proj g|=  1.47086D-01
#
# At iterate   20    f=  3.10676D+00    |proj g|=  3.83041D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     31      1     0     0   2.711D-06   3.107D+00
#   F =   3.1067586253133475
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 0)x(1, 1, 1, 12)12 - AIC:304.24882803008137
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.62082D+00    |proj g|=  2.76207D-01
#
# At iterate    5    f=  7.57452D+00    |proj g|=  1.26844D-03
#
# At iterate   10    f=  7.57422D+00    |proj g|=  2.93922D-02
#
# At iterate   15    f=  7.55111D+00    |proj g|=  2.39326D-01
#
# At iterate   20    f=  7.46798D+00    |proj g|=  2.90169D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     23     27      1     0     0   4.885D-08   7.468D+00
#   F =   7.4679711153730155
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 0, 0, 12)12 - AIC:720.9252270758095
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.87927D+01    |proj g|=  4.50773D-03
#   ys=-4.905E+04  -gs= 2.286E-02 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      2     27      2     1     0   9.173D+03   2.834D+01
#   F =   28.341779976326830
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(0, 0, 1, 12)12 - AIC:2726.8108777273756
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.81850D+00    |proj g|=  1.63640D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      3      5      1     0     0   5.549D-05   4.818D+00
#   F =   4.8183410727178577
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 0, 1)x(0, 1, 0, 12)12 - AIC:466.56074298091437
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.03608D+00    |proj g|=  1.53380D-01
#
# At iterate    5    f=  3.01401D+00    |proj g|=  3.58462D-03
#
# At iterate   10    f=  3.00248D+00    |proj g|=  9.13790D-02
#
# At iterate   15    f=  2.97527D+00    |proj g|=  7.09103D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     17     21      1     0     0   3.840D-07   2.975D+00
#   F =   2.9752722809096741
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(0, 1, 1, 12)12 - AIC:291.6261389673287
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.77847D+00    |proj g|=  3.74770D-02
#
# At iterate    5    f=  5.77414D+00    |proj g|=  8.20004D-04
#
# At iterate   10    f=  5.77045D+00    |proj g|=  3.10557D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   15    f=  5.42367D+00    |proj g|=  2.22851D+00
#
# At iterate   20    f=  5.23798D+00    |proj g|=  5.22740D-01
#
# At iterate   25    f=  5.18502D+00    |proj g|=  1.92807D-01
#
# At iterate   30    f=  5.16011D+00    |proj g|=  5.52611D-02
#
# At iterate   35    f=  5.14989D+00    |proj g|=  5.73811D-03
#
# At iterate   40    f=  5.14584D+00    |proj g|=  9.14389D-02
#
# At iterate   45    f=  5.14277D+00    |proj g|=  2.16063D-02
#
# At iterate   50    f=  5.14132D+00    |proj g|=  2.89182D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     50     71      1     0     0   2.892D-02   5.141D+00
#   F =   5.1413184589216803
#
# STOP: TOTAL NO. of ITERATIONS REACHED LIMIT
# ARIMA(0, 0, 1)x(1, 0, 0, 12)12 - AIC:499.5665720564813
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.76708D+01    |proj g|=  3.90981D-03
#   ys=-1.458E+01  -gs= 2.018E-02 BFGS update SKIPPED
#   ys=-2.986E+05  -gs= 2.734E+01 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      3     33      3     2     0   7.800D+04   2.748D+01
#   F =   27.478454034157391
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 0, 1)x(1, 0, 1, 12)12 - AIC:2645.9315872791094
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.30136D+00    |proj g|=  8.81709D-03
#
# At iterate    5    f=  3.30121D+00    |proj g|=  1.24497D-03
#
# At iterate   10    f=  3.29918D+00    |proj g|=  3.27117D-02
#
# At iterate   15    f=  3.27151D+00    |proj g|=  2.08396D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     19     22      1     0     0   1.068D-06   3.271D+00
#   F =   3.2707134134863178
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 1, 0, 12)12 - AIC:319.9884876946865
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.03608D+00    |proj g|=  1.53380D-01
#
# At iterate    5    f=  3.01570D+00    |proj g|=  2.21140D-02
#
# At iterate   10    f=  3.01390D+00    |proj g|=  1.40285D-03
#  This problem is unconstrained.
# At iterate   15    f=  3.01088D+00    |proj g|=  2.00584D-02
#
# At iterate   20    f=  2.96843D+00    |proj g|=  3.42209D-02
#
# At iterate   25    f=  2.95716D+00    |proj g|=  2.56297D-03
#
# At iterate   30    f=  2.95705D+00    |proj g|=  3.53517D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     34     45      1     0     0   4.374D-07   2.957D+00
#   F =   2.9570058088114082
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 0, 1)x(1, 1, 1, 12)12 - AIC:291.8725576458952
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.04097D+00    |proj g|=  1.08020D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      2      3      1     0     0   4.372D-06   7.041D+00
#   F =   7.0405704879317748
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 0, 0, 12)12 - AIC:677.8947668414504
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.76141D+01    |proj g|=  2.92287D-03
#   ys=-3.017E+02  -gs= 6.959E-01 BFGS update SKIPPED
#   ys=-3.588E+01  -gs= 6.949E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      5     80      4     2     0   2.033D+05   1.351D+01
#   F =   13.514465763726681
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(0, 0, 1, 12)12 - AIC:1301.3887133177614
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            1     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.06688D+00    |proj g|=  9.86171D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     1      4      6      1     0     0   4.549D-06   5.048D+00
#   F =   5.0483110074377455
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 0, 12)12 - AIC:486.63785671402354
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.18743D+00    |proj g|=  1.32769D-01
#
# At iterate    5    f=  3.16516D+00    |proj g|=  2.09181D-03
#
# At iterate   10    f=  3.16263D+00    |proj g|=  3.87590D-02
#
# At iterate   15    f=  3.13511D+00    |proj g|=  4.53866D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     18     20      1     0     0   3.611D-07   3.135D+00
#   F =   3.1350741960082953
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(0, 1, 1, 12)12 - AIC:304.96712281679635
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.14364D+00    |proj g|=  6.38920D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   6.389D-06   5.144D+00
#   F =   5.1436350656295913
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 0, 0, 12)12 - AIC:497.7889663004408
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70923D+01    |proj g|=  4.35463D-03
#   ys=-4.911E+01  -gs= 6.984E-01 BFGS update SKIPPED
#   ys=-1.911E+01  -gs= 6.798E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      5     87      2     2     0   1.058D+05   1.446D+01
#   F =   14.460616175635847
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 0)x(1, 0, 1, 12)12 - AIC:1394.2191528610413
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.28929D+00    |proj g|=  4.82157D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   4.822D-06   3.289D+00
#   F =   3.2892854876137618
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 0, 12)12 - AIC:319.7714068109211
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.18743D+00    |proj g|=  1.32769D-01
#
# At iterate    5    f=  3.16631D+00    |proj g|=  3.88243D-02
#
# At iterate   10    f=  3.16499D+00    |proj g|=  1.49204D-03
#
# At iterate   15    f=  3.16428D+00    |proj g|=  2.53544D-02
#
# At iterate   20    f=  3.14603D+00    |proj g|=  6.53180D-02
#
# At iterate   25    f=  3.13510D+00    |proj g|=  5.58366D-03
#
# At iterate   30    f=  3.13449D+00    |proj g|=  1.09424D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     30     37      1     0     0   1.094D-06   3.134D+00
#   F =   3.1344929168243980
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 0)x(1, 1, 1, 12)12 - AIC:306.9113200151422
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.74578D+00    |proj g|=  8.96878D-02
#
# At iterate    5    f=  6.73017D+00    |proj g|=  3.27993D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      9     23      1     0     0   1.284D-05   6.728D+00
#   F =   6.7281835175175830
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(0, 0, 0, 12)12 - AIC:649.905617681688
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70336D+01    |proj g|=  7.20152D-03
#   ys=-5.136E+05  -gs= 3.734E-02 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      2     30      2     1     0   8.361D+04   2.689D+01
#   F =   26.889490747799211
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(0, 1, 1)x(0, 0, 1, 12)12 - AIC:2587.391111788724
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.76190D+00    |proj g|=  1.01285D-01
#
# At iterate    5    f=  4.74718D+00    |proj g|=  5.28400D-04
#
# At iterate   10    f=  4.74705D+00    |proj g|=  1.11248D-02
#
# At iterate   15    f=  4.73828D+00    |proj g|=  3.49619D-03
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   20    f=  4.73823D+00    |proj g|=  9.13047D-08
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2     20     22      1     0     0   9.130D-08   4.738D+00
#   F =   4.7382349463364735
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 0, 12)12 - AIC:458.8705548483014
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97823D+00    |proj g|=  1.50080D-01
#
# At iterate    5    f=  2.92871D+00    |proj g|=  5.66975D-03
#
# At iterate   10    f=  2.92864D+00    |proj g|=  5.96714D-03
#
# At iterate   15    f=  2.92143D+00    |proj g|=  7.46461D-02
#
# At iterate   20    f=  2.87919D+00    |proj g|=  1.99192D-02
#
# At iterate   25    f=  2.85662D+00    |proj g|=  4.00637D-02
#
# At iterate   30    f=  2.84985D+00    |proj g|=  3.98880D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     33     43      1     0     0   8.105D-06   2.850D+00
#   F =   2.8497981597628570
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(0, 1, 1, 12)12 - AIC:279.5806233372343
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.10670D+00    |proj g|=  3.57336D-02
#
# At iterate    5    f=  5.10219D+00    |proj g|=  1.15500D-03
#
# At iterate   10    f=  5.10002D+00    |proj g|=  2.93446D-02
#
# At iterate   15    f=  5.02195D+00    |proj g|=  1.34084D-01
#
# At iterate   20    f=  5.00192D+00    |proj g|=  4.23551D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     23     27      1     0     0   1.707D-06   5.002D+00
#   F =   5.0019093515028672
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 0, 0, 12)12 - AIC:486.18329774427525
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.67928D+01    |proj g|=  6.97986D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      3     24      1     0     0   2.515D-01   2.678D+01
#   F =   26.779271325913324
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(0, 1, 1)x(1, 0, 1, 12)12 - AIC:2578.810047287679
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.23022D+00    |proj g|=  3.65785D-02
#
# At iterate    5    f=  3.22401D+00    |proj g|=  7.08917D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   10    f=  3.21896D+00    |proj g|=  1.01148D-03
#
# At iterate   15    f=  3.21872D+00    |proj g|=  3.85935D-02
#
# At iterate   20    f=  3.17691D+00    |proj g|=  3.94615D-02
#
# At iterate   25    f=  3.17456D+00    |proj g|=  7.44442D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     28     43      1     0     0   4.779D-07   3.175D+00
#   F =   3.1745566337680362
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 1, 0, 12)12 - AIC:310.7574368417315
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.97823D+00    |proj g|=  1.76039D-01
#
# At iterate    5    f=  2.93137D+00    |proj g|=  4.51405D-02
#
# At iterate   10    f=  2.92843D+00    |proj g|=  1.02500D-03
#
# At iterate   15    f=  2.92822D+00    |proj g|=  2.90989D-02
#  This problem is unconstrained.
# At iterate   20    f=  2.89347D+00    |proj g|=  2.64524D-01
#
# At iterate   25    f=  2.85822D+00    |proj g|=  2.18981D-01
#
# At iterate   30    f=  2.84956D+00    |proj g|=  8.30523D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     45      1     0     0   6.304D-06   2.850D+00
#   F =   2.8495589806887973
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(0, 1, 1)x(1, 1, 1, 12)12 - AIC:281.5576621461245
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  7.16838D+00    |proj g|=  2.51956D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      1     13      1     0     0   2.514D-05   7.168D+00
#   F =   7.1683807521538681
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 0)x(0, 0, 0, 12)12 - AIC:692.1645522067713
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.90300D+01    |proj g|=  1.92146D-03
#
# At iterate    5    f=  1.76304D+01    |proj g|=  1.37371D+04
#   ys=-1.871E+01  -gs= 6.728E-01 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Warning:  more than 10 function and gradient
#    evaluations in the last line search.  Termination
#    may possibly be caused by a bad search direction.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3      8     84      2     1     0   3.402D+05   1.294D+01
#   F =   12.936614269195681
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(0, 0, 1, 12)12 - AIC:1247.9149698427855
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            2     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.95274D+00    |proj g|=  4.17506D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     2      0      1      0     0     0   4.175D-06   4.953D+00
#   F =   4.9527418206793081
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(0, 1, 0, 12)12 - AIC:479.46321478521355
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.16805D+00    |proj g|=  1.64266D-01
#
# At iterate    5    f=  3.14466D+00    |proj g|=  1.77768D-03
#
# At iterate   10    f=  3.14134D+00    |proj g|=  3.70899D-02
#
# At iterate   15    f=  3.10841D+00    |proj g|=  4.52844D-02
#
# At iterate   20    f=  3.10633D+00    |proj g|=  1.63019D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     21     24      1     0     0   1.291D-06   3.106D+00
#   F =   3.1063309116259745
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(0, 1, 1, 12)12 - AIC:304.20776751609355
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  5.19919D+00    |proj g|=  2.41292D-01
#
# At iterate    5    f=  5.09833D+00    |proj g|=  1.23092D-02
#
# At iterate   10    f=  5.09817D+00    |proj g|=  1.03693D-02
#
# At iterate   15    f=  5.07999D+00    |proj g|=  1.97991D-01
#
# At iterate   20    f=  4.94876D+00    |proj g|=  1.37174D-01
#
# At iterate   25    f=  4.94715D+00    |proj g|=  1.23784D-05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     26     30      1     0     0   5.006D-07   4.947D+00
#   F =   4.9471451749325093
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 0, 0, 12)12 - AIC:480.9259367935209
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.78797D+01    |proj g|=  1.92431D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  2.78347D+01    |proj g|=  1.17164D-02
#   ys=-2.873E+01  -gs= 7.117E-01 BFGS update SKIPPED
#
# At iterate   10    f=  1.24799D+01    |proj g|=  2.69697D+05
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     11     97      2     1     0   2.697D+05   1.248D+01
#   F =   12.479916623485003
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 0)x(1, 0, 1, 12)12 - AIC:1206.0719958545603
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.14966D+00    |proj g|=  6.73283D-02
#
# At iterate    5    f=  3.14546D+00    |proj g|=  3.59066D-03
#
# At iterate   10    f=  3.13253D+00    |proj g|=  7.92845D-02
#
# At iterate   15    f=  3.10903D+00    |proj g|=  5.29956D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     22      1     0     0   1.329D-06   3.109D+00
#   F =   3.1090257032130992
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 1, 0, 12)12 - AIC:304.4664675084575
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.16805D+00    |proj g|=  1.64266D-01
#
# At iterate    5    f=  3.14669D+00    |proj g|=  2.12240D-02
#
# At iterate   10    f=  3.14460D+00    |proj g|=  2.49106D-03
#
# At iterate   15    f=  3.14450D+00    |proj g|=  4.78054D-03
#
# At iterate   20    f=  3.13450D+00    |proj g|=  6.55616D-02
#
# At iterate   25    f=  3.10013D+00    |proj g|=  7.09179D-02
#
# At iterate   30    f=  3.08947D+00    |proj g|=  1.52002D-02
#
# At iterate   35    f=  3.08942D+00    |proj g|=  3.72360D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     35     42      1     0     0   3.724D-06   3.089D+00
#   F =   3.0894194709831417
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 0, 0)x(1, 1, 1, 12)12 - AIC:304.5842692143816
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.90121D+00    |proj g|=  9.10067D-02
#
# At iterate    5    f=  6.87978D+00    |proj g|=  2.25690D+00
#
# At iterate   10    f=  6.87270D+00    |proj g|=  4.79554D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     11     22      1     0     0   3.643D-03   6.873D+00
#   F =   6.8727025439435652
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 0, 1)x(0, 0, 0, 12)12 - AIC:665.7794442185823
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.81159D+01    |proj g|=  7.86502D-03
#  This problem is unconstrained.
#  This problem is unconstrained.
#
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#   ys=-2.352E+01  -gs= 5.101E-02 BFGS update SKIPPED
#
# At iterate    5    f=  2.80971D+01    |proj g|=  8.70880D+01
#   ys=-7.242E-04  -gs= 2.152E-03 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#   ys=-1.527E-04  -gs= 2.929E-04 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      8    133      6     3     0   1.973D+02   2.810D+01
#   F =   28.096424267205034
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 0, 1)x(0, 0, 1, 12)12 - AIC:2705.256729651683
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.82203D+00    |proj g|=  9.77386D-02
#
# At iterate    5    f=  4.81853D+00    |proj g|=  1.78050D-02
#
# At iterate   10    f=  4.81634D+00    |proj g|=  1.74888D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# ...
#
# At iterate    0    f=  3.12416D+00    |proj g|=  1.59332D-01
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  3.09912D+00    |proj g|=  7.57367D-03
#
# At iterate   10    f=  3.07347D+00    |proj g|=  4.56418D-02
#
# At iterate   15    f=  3.06472D+00    |proj g|=  9.59964D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     18     24      1     0     0   2.558D-07   3.065D+00
#   F =   3.0647193871032274
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(0, 1, 1, 12)12 - AIC:300.2130611619098
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.95997D+00    |proj g|=  3.34294D-02
#
# At iterate    5    f=  4.95798D+00    |proj g|=  2.40641D-02
#
# At iterate   10    f=  4.90324D+00    |proj g|=  1.99571D-01
#
# At iterate   15    f=  4.88896D+00    |proj g|=  2.69482D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     15     20      1     0     0   2.695D-06   4.889D+00
#   F =   4.8889621445681124
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 0, 0, 12)12 - AIC:475.3403658785388
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.76143D+01    |proj g|=  2.01048D-03
#   ys=-7.988E+01  -gs= 6.135E-01 BFGS update SKIPPED
#   ys=-2.254E+01  -gs= 6.875E-01 BFGS update SKIPPED
#   ys=-2.750E+01  -gs= 6.910E-01 BFGS update SKIPPED
#
# At iterate    5    f=  1.64996D+01    |proj g|=  1.25638D+04
#   ys=-2.538E+01  -gs= 6.896E-01 BFGS update SKIPPED
#  Bad direction in the line search;
#    refresh the lbfgs memory and restart the iteration.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      6     89      3     4     0   1.256D+04   1.650D+01
#   F =   16.499593716019046
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 0)x(1, 0, 1, 12)12 - AIC:1591.9609967378285
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.10197D+00    |proj g|=  1.68835D-02
#
# At iterate    5    f=  3.10136D+00    |proj g|=  1.04559D-02
#
# At iterate   10    f=  3.08543D+00    |proj g|=  1.26872D-01
#
# At iterate   15    f=  3.06903D+00    |proj g|=  1.52920D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     16     19      1     0     0   3.073D-06   3.069D+00
#   F =   3.0690321889014829
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 0, 12)12 - AIC:300.62709013454236
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.12416D+00    |proj g|=  1.59332D-01
#
# At iterate    5    f=  3.09966D+00    |proj g|=  1.44150D-02
#
# At iterate   10    f=  3.09925D+00    |proj g|=  2.70334D-03
#
# At iterate   15    f=  3.09397D+00    |proj g|=  5.42311D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate   20    f=  3.06825D+00    |proj g|=  1.66823D-02
#
# At iterate   25    f=  3.06621D+00    |proj g|=  1.00832D-02
#
# At iterate   30    f=  3.06590D+00    |proj g|=  1.39138D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     39      1     0     0   5.552D-06   3.066D+00
#   F =   3.0659010338626094
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 0)x(1, 1, 1, 12)12 - AIC:302.3264992508105
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  6.74889D+00    |proj g|=  8.44414D-02
#
# At iterate    5    f=  6.71856D+00    |proj g|=  1.47337D-01
#
# At iterate   10    f=  6.71051D+00    |proj g|=  8.89737D-04
#
# At iterate   15    f=  6.70960D+00    |proj g|=  5.51612D-02
#
# At iterate   20    f=  6.69897D+00    |proj g|=  4.59317D-02
#
# At iterate   25    f=  6.69825D+00    |proj g|=  5.88809D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     33      1     0     0   5.888D-06   6.698D+00
#   F =   6.6982479373281842
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 0, 0, 12)12 - AIC:649.0318019835057
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.70329D+01    |proj g|=  6.21298D-03
#   ys=-1.093E+07  -gs= 3.363E-02 BFGS update SKIPPED
#  This problem is unconstrained.
#
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4      2     29      2     1     0   1.537D+06   1.147D+01
#   F =   11.465265772811270
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 1)x(0, 0, 1, 12)12 - AIC:1108.6655141898818
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            3     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.77247D+00    |proj g|=  5.57251D-02
#
# At iterate    5    f=  4.74738D+00    |proj g|=  7.45904D-02
#
# At iterate   10    f=  4.74215D+00    |proj g|=  5.05521D-04
#
# At iterate   15    f=  4.74189D+00    |proj g|=  1.89004D-02
#
# At iterate   20    f=  4.73466D+00    |proj g|=  2.88448D-02
#
# At iterate   25    f=  4.73413D+00    |proj g|=  7.19185D-06
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     3     25     33      1     0     0   7.192D-06   4.734D+00
#   F =   4.7341277995939564
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 0, 12)12 - AIC:460.4762687610198
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98342D+00    |proj g|=  1.71628D-01
#   ys=-4.857E-03  -gs= 6.535E-03 BFGS update SKIPPED
#  This problem is unconstrained.
# At iterate    5    f=  2.92491D+00    |proj g|=  2.97664D-02
#
# At iterate   10    f=  2.92293D+00    |proj g|=  1.02711D-03
#
# At iterate   15    f=  2.92057D+00    |proj g|=  3.20002D-02
#
# At iterate   20    f=  2.87973D+00    |proj g|=  3.06136D-02
#
# At iterate   25    f=  2.84939D+00    |proj g|=  4.57848D-02
#
# At iterate   30    f=  2.84778D+00    |proj g|=  1.98116D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     31     42      1     1     0   2.276D-06   2.848D+00
#   F =   2.8477843822285358
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(0, 1, 1, 12)12 - AIC:281.38730069393944
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94554D+00    |proj g|=  4.47276D-02
#  This problem is unconstrained.
#  This problem is unconstrained.
# At iterate    5    f=  4.92820D+00    |proj g|=  4.33012D-03
#
# At iterate   10    f=  4.92756D+00    |proj g|=  2.13740D-02
#
# At iterate   15    f=  4.86782D+00    |proj g|=  3.01010D-01
#
# At iterate   20    f=  4.80756D+00    |proj g|=  3.28928D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     24     37      1     0     0   5.431D-07   4.808D+00
#   F =   4.8075524527715894
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ARIMA(1, 1, 1)x(1, 0, 0, 12)12 - AIC:469.52503546607255
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.67922D+01    |proj g|=  6.00342D-03
#   ys=-4.742E+06  -gs= 1.585E-02 BFGS update SKIPPED
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5      2     28      2     1     0   1.335D+06   1.372D+01
#   F =   13.717668958421513
#
# ABNORMAL_TERMINATION_IN_LNSRCH
# ARIMA(1, 1, 1)x(1, 0, 1, 12)12 - AIC:1326.8962200084652
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  3.09103D+00    |proj g|=  3.72719D-02
#
# At iterate    5    f=  3.08056D+00    |proj g|=  3.47745D-02
#
# At iterate   10    f=  3.07783D+00    |proj g|=  1.16849D-03
#  Line search cannot locate an adequate point after MAXLS
#   function and gradient evaluations.
#   Previous x, f and g restored.
#  Possible causes: 1 error in function or gradient evaluation;
#                   2 rounding error dominate computation.
#  This problem is unconstrained.
#   ys=-2.589E-04  -gs= 2.696E-04 BFGS update SKIPPED
#
# At iterate   15    f=  3.07434D+00    |proj g|=  9.55769D-04
#
# At iterate   20    f=  3.07399D+00    |proj g|=  2.28399D-02
#
# At iterate   25    f=  3.04253D+00    |proj g|=  2.03787D-01
#
# At iterate   30    f=  3.01863D+00    |proj g|=  1.39081D-02
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     33     58      1     1     0   9.573D-05   3.019D+00
#   F =   3.0186202495158678
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 0, 12)12 - AIC:297.7875439535233
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            5     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  2.98342D+00    |proj g|=  1.76988D-01
#  This problem is unconstrained.
# At iterate    5    f=  2.94075D+00    |proj g|=  1.72204D-01
#
# At iterate   10    f=  2.92298D+00    |proj g|=  1.23343D-02
#
# At iterate   15    f=  2.92270D+00    |proj g|=  1.02674D-03
#
# At iterate   20    f=  2.92162D+00    |proj g|=  6.40688D-02
#
# At iterate   25    f=  2.86052D+00    |proj g|=  1.42815D-01
#
# At iterate   30    f=  2.84756D+00    |proj g|=  4.72554D-03
#
# At iterate   35    f=  2.84756D+00    |proj g|=  2.44903D-04
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     5     35     46      1     0     0   2.449D-04   2.848D+00
#   F =   2.8475635604740290
#
# CONVERGENCE: REL_REDUCTION_OF_F_<=_FACTR*EPSMCH
# ARIMA(1, 1, 1)x(1, 1, 1, 12)12 - AIC:283.3661018055068

# %%
mod = sm.tsa.statespace.SARIMAX(y,
                                order=(1, 1, 1),
                                seasonal_order=(1, 0, 0, 12),
                                enforce_stationarity=False,
                                enforce_invertibility=False)
results = mod.fit()
print(results.summary().tables[1])
# Out:
# RUNNING THE L-BFGS-B CODE
#
#            * * *
#
# Machine precision = 2.220D-16
#  N =            4     M =           10
#
# At X0         0 variables are exactly at the bounds
#
# At iterate    0    f=  4.94554D+00    |proj g|=  4.47276D-02
#
# At iterate    5    f=  4.92820D+00    |proj g|=  4.33012D-03
#
# At iterate   10    f=  4.92756D+00    |proj g|=  2.13740D-02
#
# At iterate   15    f=  4.86782D+00    |proj g|=  3.01010D-01
#
# At iterate   20    f=  4.80756D+00    |proj g|=  3.28928D-03
#
#            * * *
#
# Tit   = total number of iterations
# Tnf   = total number of function evaluations
# Tnint = total number of segments explored during Cauchy searches
# Skip  = number of BFGS updates skipped
# Nact  = number of active bounds at final generalized Cauchy point
# Projg = norm of the final projected gradient
# F     = final function value
#
#            * * *
#
#    N    Tit     Tnf  Tnint  Skip  Nact     Projg        F
#     4     24     37      1     0     0   5.431D-07   4.808D+00
#   F =   4.8075524527715894
#
# CONVERGENCE: NORM_OF_PROJECTED_GRADIENT_<=_PGTOL
# ==============================================================================
#                  coef    std err          z      P>|z|      [0.025      0.975]
# ------------------------------------------------------------------------------
# ar.L1          0.1732      0.132      1.315      0.189      -0.085       0.431
# ma.L1         -1.0000      0.279     -3.587      0.000      -1.546      -0.454
# ar.S.L12       0.7030      0.101      6.952      0.000       0.505       0.901
# sigma2      4.203e+04   6.63e-06   6.34e+09      0.000     4.2e+04     4.2e+04
# ==============================================================================
#  This problem is unconstrained.

# %%
#set forecasts to start at 2017–01–01 to the end of the data to forecast
pred = results.get_prediction(start=pd.to_datetime('2017-01-01'), dynamic=False)
pred_ci = pred.conf_int()
ax = y['2014':].plot(label='observed')
pred.predicted_mean.plot(ax=ax, label='One-step ahead Forecast',alpha=1, figsize=(14, 7))
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.2)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
plt.legend()
plt.show()

# %%
y_forecasted = pred.predicted_mean
y_truth = y['2017-01-01':]
mse = ((y_forecasted - y_truth) ** 2).mean()
print('The Root Mean Squared Error of our forecasts is {}'.format(round(np.sqrt(mse), 2)))
# Out:
# The Root Mean Squared Error of our forecasts is 161.1

# %%
pred_uc = results.get_forecast(steps=13)
pred_ci = pred_uc.conf_int()
ax = y.plot(label='observed', figsize=(14, 7))
pred_uc.predicted_mean.plot(ax=ax, label='Forecast')
ax.fill_between(pred_ci.index,
                pred_ci.iloc[:, 0],
                pred_ci.iloc[:, 1], color='k', alpha=.25)
ax.set_xlabel('Date')
ax.set_ylabel('Furniture Sales')
print(pred_ci)
plt.legend()
plt.show()
# Out:
#             lower Sales  upper Sales
# 2018-01-01   122.817486   937.536875
# 2018-02-01   204.280250  1034.875421
# 2018-03-01   214.899931  1046.614110
# 2018-04-01   150.515620   982.375421
# 2018-05-01   308.677703  1140.561278
# 2018-06-01   412.834036  1244.721684
# 2018-07-01   227.276940  1059.165292
# 2018-08-01   434.923729  1266.812203
# 2018-09-01   682.130277  1514.018772
# 2018-10-01   447.213380  1279.101879
# 2018-11-01   730.154149  1562.042648
# 2018-12-01   715.025435  1546.913934
# 2019-01-01   107.971754  1132.987095

# %% [markdown]
# # Diagnostics

# %%
results.plot_diagnostics(figsize=(16,8))
plt.show()
